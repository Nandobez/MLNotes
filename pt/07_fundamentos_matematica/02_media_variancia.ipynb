# %% [markdown]
# # Média [WIP]
#
# > Parte da série [ML Notebooks](../README.md) — por **Nandobez**.
#
#
# A média (aritmética) é uma medida de tendência central de um conjunto de números. Calcula-se como:
#
# $$
# m = \frac{\text{soma dos termos}}{\text{número de termos}}
# $$
#
# ou, mais formalmente:
#
# $$
# \bar{x} = \frac{1}{n}\!\left(\sum_{i=1}^{n} x_{i}\right) = \frac{x_{1} + x_{2} + \cdots + x_{n}}{n}
# $$

# %%
import torch
x = torch.randn(5, 3)
print(x)

# use keepdim=True to preserve dimension
x.mean(-1, keepdim=True)

# %%
# Example 2:
import torch

x = torch.Tensor([4, 36, 45, 50, 75])

print(torch.sum(x) / 5) # using sum and manual division
print(torch.mean(x))    # using mean function

# %% [markdown]
# ### Referências
#
# - [Wikipedia — Mean](https://en.wikipedia.org/wiki/Mean)
# - [Basics of Statistics for ML Engineer](https://medium.com/technology-nineleaps/basics-of-statistics-for-machine-learning-engineers-bf2887ac716c)

# %% [markdown]
# ## References
#
# - Series repo: [github.com/Nandobez/ml-notebooks](https://github.com/Nandobez/ml-notebooks)
# - Author: [Nandobez](https://github.com/Nandobez)
